# %% [markdown]
# # 第二课 词向量
#
# 第二课学习目标
# - 学习词向量的概念
# - 用skip-gram模型训练词向量
# - 学习使用PyTorch dataset和dataloader
# - 学习定义PyTorch模型
# - 学习torch.nn中常见的Module
#     - Embedding
# - 学习常见的PyTorch operations
#     - bmm
#     - logsigmoid
# - 保存和读取PyTorch模型
#
#
# 第二课使用的训练数据可以从以下链接下载到。
#
# 链接:https://pan.baidu.com/s/1tFeK3mXuVXEy3EMarfeWvg  密码:v2z5
#
# 在这一份notebook中，我们会（尽可能）尝试复现论文[Distributed Representations of Words and Phrases and their Compositionality](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf)中训练词向量的方法. 我们会实现Skip-gram模型，并且使用论文中negative sampling的目标函数。
#
# 这篇论文有很多模型实现的细节，这些细节对于词向量的好坏至关重要。我们虽然无法完全复现论文中的实验结果，主要是由于计算资源等各种细节原因，但是我们还是可以大致展示如何训练词向量。
#
# 以下是一些我们没有实现的细节
# - subsampling：参考论文section 2.3

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.utils.data as tud
from torch.nn.parameter import Parameter

from collections import Counter
import numpy as np
import random
import math

import pandas as pd
import scipy
import sklearn
from sklearn.metrics.pairwise import cosine_similarity

USE_CUDA = torch.cuda.is_available()

# 为了保证实验结果可以复现，我们经常会把各种random seed固定在某一个值
random.seed(53113)
np.random.seed(53113)
torch.manual_seed(53113)
if USE_CUDA:
    torch.cuda.manual_seed(53113)
    
# 设定一些超参数
K = 100 # number of negative samples
C = 3 # nearby words threshold
NUM_EPOCHS = 2 # The number of epochs of training
MAX_VOCAB_SIZE = 30000 # the maximum vocabulary size
BATCH_SIZE = 128 # the batch size
LEARNING_RATE = 0.2 # the initial learning rate
EMBEDDING_SIZE = 100
       
    
LOG_FILE = "word-embedding.log"

print(USE_CUDA)
# Out:
# True

# %% [markdown]
# ### 数据预处理
# - 从文本文件中读取所有的文字，通过这些文本创建一个vocabulary
# - 由于单词数量可能太大，我们只选取最常见的MAX_VOCAB_SIZE个单词
# - 我们添加一个UNK单词表示所有不常见的单词
# - 我们需要记录单词到index的mapping，以及index到单词的mapping，单词的count，单词的(normalized) frequency，以及单词总数。

# %%
with open("text8/text8.train.txt", "r") as fin:
    text = fin.read()

# tokenize函数，把一篇文本转化成一个个单词
def word_tokenize(text):
    return text.split()

text = [w for w in word_tokenize(text.lower())]
vocab = dict(Counter(text).most_common(MAX_VOCAB_SIZE-1))#Counter计算单词频数，count最高取vocab_size-1个,最后一个取unk
vocab["<unk>"] = len(text) - np.sum(list(vocab.values()))#unk频率单独计算
idx_to_word = [word for word in vocab.keys()]
word_to_idx = {word:i for i, word in enumerate(idx_to_word)}#enumerate自带index

word_counts = np.array([count for count in vocab.values()], dtype=np.float32)
word_freqs = word_counts / np.sum(word_counts)
word_freqs = word_freqs ** (3./4.)
word_freqs = word_freqs / np.sum(word_freqs) # normalization
VOCAB_SIZE = len(idx_to_word)

# %% [markdown]
# ### 实现Dataloader
#
# 一个dataloader需要以下内容：
#
# - 把所有text编码成数字，然后用subsampling预处理这些文字。
# - 保存vocabulary，单词count，normalized word frequency
# - 每个iteration sample一个中心词
# - 根据当前的中心词返回context单词
# - 根据中心词sample一些negative单词
# - 返回单词的counts
#
# 这里有一个好的tutorial介绍如何使用[PyTorch dataloader](https://pytorch.org/tutorials/beginner/data_loading_tutorial.html).
# 为了使用dataloader，我们需要定义以下两个function:
#
# - ```__len__``` function需要返回整个数据集中有多少个item
# - ```__get__``` 根据给定的index返回一个item
#
# 有了dataloader之后，我们可以轻松随机打乱整个数据集，拿到一个batch的数据等等。

# %%
class WordEmbeddingDataset(tud.Dataset): #继承类，创建specific dataset
    def __init__(self, text, word_to_idx, idx_to_word, word_freqs, word_counts):
        ''' text: a list of words, all text from the training dataset
            word_to_idx: mapping word to idx
            idx_to_word: list of words
            word_freq: the frequency of each word
            word_counts: the word counts
        '''
        super(WordEmbeddingDataset, self).__init__()
        self.text_encoded = [word_to_idx.get(t, VOCAB_SIZE-1) for t in text]#找text每个单词的idx
        self.text_encoded = torch.Tensor(self.text_encoded).long()#must be integars
        self.word_to_idx = word_to_idx
        self.idx_to_word = idx_to_word
        self.word_freqs = torch.Tensor(word_freqs)
        self.word_counts = torch.Tensor(word_counts)
        
    def __len__(self):
        ''' 返回整个数据集的长度（所有单词的个数）
        '''
        return len(self.text_encoded)
        
    def __getitem__(self, idx):
        ''' 这个function返回以下数据用于训练
            - 中心词
            - 这个单词附近的(positive)单词
            - 随机采样的K个单词作为negative sample
            - K,C: previously defined hyper parameters
        '''
        center_word = self.text_encoded[idx]
        pos_indices = list(range(idx-C, idx)) + list(range(idx+1, idx+C+1))#omit idx
        pos_indices = [i%len(self.text_encoded) for i in pos_indices]#超出范围取余
        pos_words = self.text_encoded[pos_indices] 
        neg_words = torch.multinomial(self.word_freqs, K * pos_words.shape[0], True)#每个pos_word取K个neg_word
        
        return center_word, pos_words, neg_words

# %% [markdown]
# 创建dataset和dataloader

# %%
dataset = WordEmbeddingDataset(text, word_to_idx, idx_to_word, word_freqs, word_counts)
dataloader = tud.DataLoader(dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=4)

# %%
dataset.text_encoded[:100]
# Out:
# tensor([ 5266,  3106,    11,     5,   194,     1,  3079,    45,    59,   154,
#           127,   744,   457, 10524,   135,     0, 25748,     1,     0,   100,
#           866,     2,     0, 16271, 29999,     1,     0,   153,   866,  3539,
#             0,   194,    10,   186,    59,     4,     5, 10679,   215,     6,
#          1354,   104,   429,    19,    59,  2846,   359,     6,  3658,     0,
#           725,     1,   366,    26,    40,    37,    53,   527,    97,    11,
#             5,  1425,  2980,    18,   565,   712,  7095,     0,   252,  5266,
#            10,  1039,    27,     0,   312,   247, 29999,  2947,   780,   179,
#          5266,    11,     5,   199,   575,    10,     0,  1105,    19,  2558,
#            25,  8777,     2,   275,    31,  3989,   142,    58,    25,  6525])

# %% [markdown]
# ### 定义PyTorch模型

# %%
class EmbeddingModel(nn.Module):
    def __init__(self, vocab_size, embed_size):
        ''' 初始化输出和输出embedding
        '''
        super(EmbeddingModel, self).__init__() #初始化
        self.vocab_size = vocab_size #存储初始信息
        self.embed_size = embed_size
        
        initrange = 0.5 / self.embed_size
        
        self.in_embed = nn.Embedding(self.vocab_size, self.embed_size, sparse=False)
        self.in_embed.weight.data.uniform_(-initrange, initrange)
        
        self.out_embed = nn.Embedding(self.vocab_size, self.embed_size, sparse=False)
        self.out_embed.weight.data.uniform_(-initrange, initrange)
        
        
    def forward(self, input_labels, pos_labels, neg_labels):
        '''
        input_labels: 中心词, [batch_size]
        pos_labels: 中心词周围 context window 出现过的单词 [batch_size * (window_size * 2)]
        neg_labelss: 中心词周围没有出现过的单词，从 negative sampling 得到 [batch_size, (window_size * 2 * K)]
        
        return: -loss
        '''
        batch_size = input_labels.size(0)
        input_embedding = self.in_embed(input_labels) # batch_size * embed_size
        pos_embedding = self.out_embed(pos_labels) # batch_size * (2*C) * embed_size
        neg_embedding = self.out_embed(neg_labels) # batch_size * (2*C * K) * embed_size
      
        #batch matrix multiply
        log_pos = torch.bmm(pos_embedding, input_embedding.unsqueeze(2)).squeeze() # B * (2*C)
        log_neg = torch.bmm(neg_embedding, -input_embedding.unsqueeze(2)).squeeze() # B * (2*C*K)
        #unsqueeze(2)在第3个维度加一
        #squeeze(2)去掉第3个维度
        log_pos = F.logsigmoid(log_pos).sum(1)
        log_neg = F.logsigmoid(log_neg).sum(1) # batch_size
        
        # objective function
        loss = log_pos + log_neg     
        return -loss #[batch_size]
    
    #一般取input embedding作为word embedding
    def input_embeddings(self):
        return self.in_embed.weight.data.cpu().numpy()

# %% [markdown]
# 定义一个模型以及把模型移动到GPU

# %%
model = EmbeddingModel(VOCAB_SIZE, EMBEDDING_SIZE)
if USE_CUDA:
    model = model.cuda()

# %% [markdown]
# 下面是评估模型的代码，以及训练模型的代码

# %%
def evaluate(filename, embedding_weights): 
    if filename.endswith(".csv"):
        data = pd.read_csv(filename, sep=",")
    else:
        data = pd.read_csv(filename, sep="\t")
    human_similarity = []
    model_similarity = []
    for i in data.iloc[:, 0:2].index:
        word1, word2 = data.iloc[i, 0], data.iloc[i, 1]
        if word1 not in word_to_idx or word2 not in word_to_idx:
            continue
        else:
            word1_idx, word2_idx = word_to_idx[word1], word_to_idx[word2]
            word1_embed, word2_embed = embedding_weights[[word1_idx]], embedding_weights[[word2_idx]]
            model_similarity.append(float(sklearn.metrics.pairwise.cosine_similarity(word1_embed, word2_embed)))
            human_similarity.append(float(data.iloc[i, 2]))

    return scipy.stats.spearmanr(human_similarity, model_similarity)# , model_similarity

def find_nearest(word):
    index = word_to_idx[word]
    embedding = embedding_weights[index]
    cos_dis = np.array([scipy.spatial.distance.cosine(e, embedding) for e in embedding_weights])
    return [idx_to_word[i] for i in cos_dis.argsort()[:10]]

# %% [markdown]
# 训练模型：
# - 模型一般需要训练若干个epoch
# - 每个epoch我们都把所有的数据分成若干个batch
# - 把每个batch的输入和输出都包装成cuda tensor
# - forward pass，通过输入的句子预测每个单词的下一个单词
# - 清空模型当前gradient
# - 用模型的预测和正确的下一个单词计算cross entropy loss
# - backward pass
# - 更新模型参数
# - 每隔一定的iteration输出模型在当前iteration的loss，以及在验证数据集上做模型的评估

# %%
optimizer = torch.optim.SGD(model.parameters(), lr=LEARNING_RATE)
# loss function defined in the model class
for e in range(NUM_EPOCHS):
    for i, (input_labels, pos_labels, neg_labels) in enumerate(dataloader):
        
        #input_labels = input_labels.long()
        #pos_labels = pos_labels.long()
        #neg_labels = neg_labels.long()
        if USE_CUDA:
            input_labels = input_labels.cuda()
            pos_labels = pos_labels.cuda()
            neg_labels = neg_labels.cuda()
            
        optimizer.zero_grad()
        loss = model(input_labels, pos_labels, neg_labels).mean()
        loss.backward()
        optimizer.step()

        if i % 100 == 0:
            with open(LOG_FILE, "a") as fout:
                fout.write("epoch: {}, iter: {}, loss: {}\n".format(e, i, loss.item()))
                #print("epoch: {}, iter: {}, loss: {}".format(e, i, loss.item()))
                    
        if i % 2000 == 0:
            embedding_weights = model.input_embeddings()
            sim_simlex = evaluate("simlex-999.txt", embedding_weights)
            sim_men = evaluate("men.txt", embedding_weights)
            sim_353 = evaluate("wordsim353.csv", embedding_weights)
            with open(LOG_FILE, "a") as fout:
                print("epoch: {}, iteration: {}, simlex-999: {}, men: {}, sim353: {}, nearest to monster: {}\n".format(
                    e, i, sim_simlex, sim_men, sim_353, find_nearest("monster")))
                fout.write("epoch: {}, iteration: {}, simlex-999: {}, men: {}, sim353: {}, nearest to monster: {}\n".format(
                    e, i, sim_simlex, sim_men, sim_353, find_nearest("monster")))
                
    embedding_weights = model.input_embeddings()
    np.save("embedding-{}".format(EMBEDDING_SIZE), embedding_weights)
    torch.save(model.state_dict(), "embedding-{}.th".format(EMBEDDING_SIZE))
# Out:
# epoch: 0, iteration: 0, simlex-999: SpearmanrResult(correlation=0.03713791534559179, pvalue=0.2518091524433883), men: SpearmanrResult(correlation=0.011393483425250336, pvalue=0.5628051875375095), sim353: SpearmanrResult(correlation=-0.06666669748453351, pvalue=0.23508863789549178), nearest to monster: ['monster', 'vale', 'elephant', 'tiberian', 'oklahoma', 'erupt', 'fernand', 'flea', 'analyst', 'wilbur']
#
# epoch: 0, iteration: 2000, simlex-999: SpearmanrResult(correlation=0.00023649031909259632, pvalue=0.9941795842225473), men: SpearmanrResult(correlation=0.03708396136775797, pvalue=0.0595518353101736), sim353: SpearmanrResult(correlation=0.047059062739889246, pvalue=0.4022180528156015), nearest to monster: ['monster', 'suggests', 'involve', 'possession', 'composers', 'visit', 'signals', 'prominent', 'governments', 'proposal']
#
# epoch: 0, iteration: 4000, simlex-999: SpearmanrResult(correlation=0.026476878033442917, pvalue=0.4140087477250364), men: SpearmanrResult(correlation=0.029435201375060522, pvalue=0.1348356650441168), sim353: SpearmanrResult(correlation=0.053609543204778454, pvalue=0.33986864155987506), nearest to monster: ['monster', 'doesn', 'handed', 'encountered', 'infection', 'metals', 'diseases', 'demographic', 'patients', 'emergency']
#
# epoch: 0, iteration: 6000, simlex-999: SpearmanrResult(correlation=0.05299275590941722, pvalue=0.1018845966494249), men: SpearmanrResult(correlation=0.04271412787315095, pvalue=0.029977395699735104), sim353: SpearmanrResult(correlation=0.06294331707073154, pvalue=0.26232948152795565), nearest to monster: ['monster', 'encountered', 'canal', 'laboratory', 'moves', 'else', 'judicial', 'goals', 'masters', 'disc']
#
# epoch: 0, iteration: 8000, simlex-999: SpearmanrResult(correlation=0.04653963487676938, pvalue=0.15090040636892538), men: SpearmanrResult(correlation=0.054476296654470784, pvalue=0.005625613776011411), sim353: SpearmanrResult(correlation=0.05826321420747368, pvalue=0.299544461954954), nearest to monster: ['monster', 'canal', 'longest', 'moves', 'returns', 'involvement', 'contest', 'southeast', 'couple', 'reserve']
#
# epoch: 0, iteration: 10000, simlex-999: SpearmanrResult(correlation=0.059218885577595824, pvalue=0.06750546019366187), men: SpearmanrResult(correlation=0.056528796770881004, pvalue=0.00406174490499249), sim353: SpearmanrResult(correlation=0.06134539095489961, pvalue=0.27466095266354784), nearest to monster: ['monster', 'canal', 'disc', 'couple', 'surviving', 'returns', 'dimension', 'dragon', 'bears', 'trading']
#
# epoch: 0, iteration: 12000, simlex-999: SpearmanrResult(correlation=0.06388959593740834, pvalue=0.048520689491588255), men: SpearmanrResult(correlation=0.0596536558079738, pvalue=0.0024258773228052356), sim353: SpearmanrResult(correlation=0.06670218641619802, pvalue=0.23483896376623972), nearest to monster: ['monster', 'contest', 'ruling', 'hills', 'palestinian', 'latest', 'couple', 'memorial', 'institution', 'door']
#
# epoch: 0, iteration: 14000, simlex-999: SpearmanrResult(correlation=0.06554374993501978, pvalue=0.04297374272697896), men: SpearmanrResult(correlation=0.06139916401303355, pvalue=0.0018003393661496958), sim353: SpearmanrResult(correlation=0.07198467692682387, pvalue=0.1997358554260236), nearest to monster: ['monster', 'ruling', 'latest', 'institution', 'camera', 'couple', 'door', 'contest', 'forming', 'node']
#
# epoch: 0, iteration: 16000, simlex-999: SpearmanrResult(correlation=0.06551847427237537, pvalue=0.04305429232228743), men: SpearmanrResult(correlation=0.06277273205057013, pvalue=0.0014163516953846062), sim353: SpearmanrResult(correlation=0.07354914733103454, pvalue=0.190111876301399), nearest to monster: ['monster', 'institution', 'door', 'longest', 'marks', 'contest', 'couple', 'ruling', 'owner', 'moves']
#
# epoch: 0, iteration: 18000, simlex-999: SpearmanrResult(correlation=0.0671532613828938, pvalue=0.03809999637676624), men: SpearmanrResult(correlation=0.06376694491546799, pvalue=0.001187169730617504), sim353: SpearmanrResult(correlation=0.07906120686836521, pvalue=0.15891174273989989), nearest to monster: ['monster', 'owner', 'door', 'marks', 'sword', 'institution', 'ruling', 'contest', 'charter', 'reserve']
#
# epoch: 0, iteration: 20000, simlex-999: SpearmanrResult(correlation=0.06889739409267757, pvalue=0.03335656788014417), men: SpearmanrResult(correlation=0.06585571642030455, pvalue=0.0008128941095632816), sim353: SpearmanrResult(correlation=0.08801680180626828, pvalue=0.1166699670149853), nearest to monster: ['monster', 'door', 'owner', 'forming', 'contest', 'ruling', 'estate', 'latest', 'charter', 'institution']
#
# epoch: 0, iteration: 22000, simlex-999: SpearmanrResult(correlation=0.07088208422745955, pvalue=0.028581514734569), men: SpearmanrResult(correlation=0.06870234955567112, pvalue=0.0004768463372111718), sim353: SpearmanrResult(correlation=0.09098474855489906, pvalue=0.10479772837891438), nearest to monster: ['monster', 'owner', 'door', 'contest', 'forming', 'charter', 'couple', 'representative', 'ruling', 'institution']
#
# epoch: 0, iteration: 24000, simlex-999: SpearmanrResult(correlation=0.07202021483184744, pvalue=0.026117968673668918), men: SpearmanrResult(correlation=0.07053347504723903, pvalue=0.00033479075456448176), sim353: SpearmanrResult(correlation=0.09570570065720825, pvalue=0.08790244611670274), nearest to monster: ['monster', 'door', 'contest', 'owner', 'latest', 'forming', 'ruling', 'plain', 'charter', 'representative']
#
# epoch: 0, iteration: 26000, simlex-999: SpearmanrResult(correlation=0.07322829429883877, pvalue=0.023705670166017566), men: SpearmanrResult(correlation=0.07223147771004827, pvalue=0.00023939373501262245), sim353: SpearmanrResult(correlation=0.10339959013916354, pvalue=0.06511425744833996), nearest to monster: ['monster', 'door', 'owner', 'ruling', 'charter', 'plain', 'latest', 'contest', 'sample', 'belt']
#
# epoch: 0, iteration: 28000, simlex-999: SpearmanrResult(correlation=0.07550876457094037, pvalue=0.01967420281167434), men: SpearmanrResult(correlation=0.07490142471342337, pvalue=0.00013924592548601888), sim353: SpearmanrResult(correlation=0.10333083033406355, pvalue=0.06529402206728781), nearest to monster: ['monster', 'door', 'plain', 'owner', 'ruling', 'sample', 'contest', 'latest', 'belt', 'frontier']
#
# epoch: 0, iteration: 30000, simlex-999: SpearmanrResult(correlation=0.07779650745076905, pvalue=0.016244070164220203), men: SpearmanrResult(correlation=0.0778728565101073, pvalue=7.461049226758972e-05), sim353: SpearmanrResult(correlation=0.10880721610154395, pvalue=0.05219789621264027), nearest to monster: ['monster', 'door', 'plain', 'camera', 'owner', 'ruling', 'loop', 'contest', 'belt', 'sample']
#
# epoch: 0, iteration: 32000, simlex-999: SpearmanrResult(correlation=0.07881149475561113, pvalue=0.014898433031321094), men: SpearmanrResult(correlation=0.07724368635012002, pvalue=8.530566558081618e-05), sim353: SpearmanrResult(correlation=0.11673872585997154, pvalue=0.03716328405413319), nearest to monster: ['monster', 'door', 'plain', 'owner', 'contest', 'frontier', 'camera', 'bird', 'leg', 'column']
#
# epoch: 0, iteration: 34000, simlex-999: SpearmanrResult(correlation=0.08152003703808101, pvalue=0.011775802986469967), men: SpearmanrResult(correlation=0.08013383244995277, pvalue=4.572727016424781e-05), sim353: SpearmanrResult(correlation=0.11960527807502976, pvalue=0.03271985352064921), nearest to monster: ['monster', 'plain', 'bird', 'door', 'owner', 'camera', 'contest', 'leg', 'forming', 'loop']
#
# epoch: 0, iteration: 36000, simlex-999: SpearmanrResult(correlation=0.08166385623418905, pvalue=0.011627534389551721), men: SpearmanrResult(correlation=0.08362130115482203, pvalue=2.0953855968116025e-05), sim353: SpearmanrResult(correlation=0.11744341065446641, pvalue=0.03602607886404013), nearest to monster: ['monster', 'plain', 'bird', 'leg', 'door', 'camera', 'owner', 'contest', 'proposal', 'frontier']
#
# epoch: 0, iteration: 38000, simlex-999: SpearmanrResult(correlation=0.08329565803112483, pvalue=0.010057539653950521), men: SpearmanrResult(correlation=0.08418671351740548, pvalue=1.8410369502264115e-05), sim353: SpearmanrResult(correlation=0.11910103950429643, pvalue=0.03346694174198324), nearest to monster: ['monster', 'plain', 'bird', 'owner', 'leg', 'contest', 'camera', 'proposal', 'loop', 'brand']
#
# epoch: 0, iteration: 40000, simlex-999: SpearmanrResult(correlation=0.0837898953153938, pvalue=0.009620744928084497), men: SpearmanrResult(correlation=0.0860821082262293, pvalue=1.18604517680745e-05), sim353: SpearmanrResult(correlation=0.1225201762643495, pvalue=0.028674020208436693), nearest to monster: ['monster', 'leg', 'plain', 'owner', 'door', 'belt', 'bird', 'camera', 'contest', 'curve']
#
# epoch: 0, iteration: 42000, simlex-999: SpearmanrResult(correlation=0.0872799786808293, pvalue=0.006987869996542572), men: SpearmanrResult(correlation=0.08775123146799718, pvalue=7.99216318212231e-06), sim353: SpearmanrResult(correlation=0.12708494009969767, pvalue=0.02320083891579272), nearest to monster: ['monster', 'plain', 'owner', 'leg', 'bird', 'belt', 'contest', 'frontier', 'camera', 'door']
#
# epoch: 0, iteration: 44000, simlex-999: SpearmanrResult(correlation=0.09023473418205052, pvalue=0.005285346833463055), men: SpearmanrResult(correlation=0.08801314663032023, pvalue=7.507307277831975e-06), sim353: SpearmanrResult(correlation=0.13011499247874136, pvalue=0.020088212615231853), nearest to monster: ['monster', 'bird', 'belt', 'leg', 'plain', 'contest', 'camera', 'curve', 'loop', 'initiative']
#
# epoch: 0, iteration: 46000, simlex-999: SpearmanrResult(correlation=0.0928202129444619, pvalue=0.004112962311585689), men: SpearmanrResult(correlation=0.08900198841368326, pvalue=5.918140105571441e-06), sim353: SpearmanrResult(correlation=0.13989274766687237, pvalue=0.012381998626242504), nearest to monster: ['monster', 'bird', 'curve', 'plain', 'belt', 'leg', 'contest', 'titled', 'loop', 'initiative']
#
# epoch: 0, iteration: 48000, simlex-999: SpearmanrResult(correlation=0.0936617999938325, pvalue=0.0037855980508935223), men: SpearmanrResult(correlation=0.08899677146605688, pvalue=5.925609949640622e-06), sim353: SpearmanrResult(correlation=0.13698247043219644, pvalue=0.014343904423613347), nearest to monster: ['monster', 'bird', 'plain', 'belt', 'leg', 'curve', 'tail', 'replacing', 'camera', 'disc']
#
# epoch: 0, iteration: 50000, simlex-999: SpearmanrResult(correlation=0.09606974916207989, pvalue=0.002975302545732995), men: SpearmanrResult(correlation=0.0908887728073449, pvalue=3.7332422807495447e-06), sim353: SpearmanrResult(correlation=0.14032489934516212, pvalue=0.012111812831001177), nearest to monster: ['monster', 'plain', 'contest', 'belt', 'bird', 'frontier', 'leg', 'door', 'replacing', 'disc']
#
# epoch: 0, iteration: 52000, simlex-999: SpearmanrResult(correlation=0.09714770625100697, pvalue=0.0026666211759889817), men: SpearmanrResult(correlation=0.09191846737610895, pvalue=2.8921615768798097e-06), sim353: SpearmanrResult(correlation=0.14708812856185266, pvalue=0.008511133076924365), nearest to monster: ['monster', 'plain', 'bird', 'mouse', 'tube', 'triple', 'frontier', 'curve', 'blade', 'contest']
#
# epoch: 0, iteration: 54000, simlex-999: SpearmanrResult(correlation=0.09921517439933074, pvalue=0.0021549439883329123), men: SpearmanrResult(correlation=0.09314526002512785, pvalue=2.126199020992846e-06), sim353: SpearmanrResult(correlation=0.14948178306734988, pvalue=0.007486498095954935), nearest to monster: ['monster', 'bird', 'plain', 'mouse', 'tube', 'leg', 'door', 'blade', 'belt', 'brand']
#
# epoch: 0, iteration: 56000, simlex-999: SpearmanrResult(correlation=0.10100985821349603, pvalue=0.00178542329243382), men: SpearmanrResult(correlation=0.0947051475724783, pvalue=1.429857590580369e-06), sim353: SpearmanrResult(correlation=0.15624371841674017, pvalue=0.005160441287987102), nearest to monster: ['monster', 'bird', 'leg', 'mouse', 'horn', 'missile', 'plain', 'tail', 'blade', 'tube']
#
# epoch: 0, iteration: 58000, simlex-999: SpearmanrResult(correlation=0.10190995433772222, pvalue=0.0016228754984365535), men: SpearmanrResult(correlation=0.09575834009499232, pvalue=1.0899917466356487e-06), sim353: SpearmanrResult(correlation=0.16253043479056029, pvalue=0.0036042429379573096), nearest to monster: ['monster', 'bird', 'leg', 'brand', 'mouse', 'missile', 'blade', 'disc', 'tube', 'triple']
#
# epoch: 0, iteration: 60000, simlex-999: SpearmanrResult(correlation=0.1037070012171741, pvalue=0.0013382898589492957), men: SpearmanrResult(correlation=0.09656537353026559, pvalue=8.836233423865526e-07), sim353: SpearmanrResult(correlation=0.1646555194121589, pvalue=0.003183361650237676), nearest to monster: ['monster', 'bird', 'brand', 'leg', 'blade', 'triple', 'door', 'diamond', 'tube', 'mouse']
#
# epoch: 0, iteration: 62000, simlex-999: SpearmanrResult(correlation=0.10447249276622052, pvalue=0.0012316547588030406), men: SpearmanrResult(correlation=0.09792280552080765, pvalue=6.184504495877176e-07), sim353: SpearmanrResult(correlation=0.1649272315452153, pvalue=0.0031328919839620603), nearest to monster: ['monster', 'bird', 'triple', 'brand', 'leg', 'blade', 'mouse', 'cave', 'tail', 'loop']
#
# epoch: 0, iteration: 64000, simlex-999: SpearmanrResult(correlation=0.10671898320833993, pvalue=0.0009622835319471281), men: SpearmanrResult(correlation=0.09868984920721237, pvalue=5.044650758572786e-07), sim353: SpearmanrResult(correlation=0.16771699428278047, pvalue=0.002655143042435904), nearest to monster: ['monster', 'bird', 'brand', 'leg', 'blade', 'diamond', 'triple', 'mouse', 'cave', 'missile']
#
# epoch: 0, iteration: 66000, simlex-999: SpearmanrResult(correlation=0.10788723048101999, pvalue=0.0008448140877531735), men: SpearmanrResult(correlation=0.0998713447864718, pvalue=3.67507749827936e-07), sim353: SpearmanrResult(correlation=0.16820810934232536, pvalue=0.0025782514122329892), nearest to monster: ['monster', 'bird', 'brand', 'leg', 'diamond', 'blade', 'cave', 'giant', 'mouse', 'tube']
#
# epoch: 0, iteration: 68000, simlex-999: SpearmanrResult(correlation=0.11059037149294862, pvalue=0.0006220456581399878), men: SpearmanrResult(correlation=0.1015105573241707, pvalue=2.354082737911073e-07), sim353: SpearmanrResult(correlation=0.1713124666720416, pvalue=0.0021373142097517823), nearest to monster: ['monster', 'bird', 'brand', 'blade', 'diamond', 'cave', 'triple', 'tube', 'mouse', 'leg']
#
# epoch: 0, iteration: 70000, simlex-999: SpearmanrResult(correlation=0.11115940915283369, pvalue=0.0005827215842051425), men: SpearmanrResult(correlation=0.10362354940505064, pvalue=1.31226492795858e-07), sim353: SpearmanrResult(correlation=0.1745155275929498, pvalue=0.0017554879816328581), nearest to monster: ['monster', 'bird', 'blade', 'brand', 'replacing', 'leg', 'diamond', 'belt', 'cave', 'tube']
#
# epoch: 0, iteration: 72000, simlex-999: SpearmanrResult(correlation=0.11086531571815524, pvalue=0.0006027472667164603), men: SpearmanrResult(correlation=0.10626499450157055, pvalue=6.218559647585987e-08), sim353: SpearmanrResult(correlation=0.17824020187405204, pvalue=0.0013905297291272427), nearest to monster: ['monster', 'bird', 'blade', 'plain', 'diamond', 'belt', 'brand', 'leg', 'tube', 'mouse']
#
# epoch: 0, iteration: 74000, simlex-999: SpearmanrResult(correlation=0.11291057706225548, pvalue=0.00047572821468333965), men: SpearmanrResult(correlation=0.10865375790799604, pvalue=3.116117347733076e-08), sim353: SpearmanrResult(correlation=0.17972075574193103, pvalue=0.0012658954326198156), nearest to monster: ['monster', 'bird', 'blade', 'mouse', 'belt', 'tube', 'plain', 'brand', 'elephant', 'cave']
#
# epoch: 0, iteration: 76000, simlex-999: SpearmanrResult(correlation=0.11322174653324031, pvalue=0.0004587474375173637), men: SpearmanrResult(correlation=0.10991652017405777, pvalue=2.149719934125714e-08), sim353: SpearmanrResult(correlation=0.18101831980591485, pvalue=0.0011651944525488396), nearest to monster: ['monster', 'bird', 'blade', 'mouse', 'belt', 'plain', 'horn', 'tube', 'cave', 'elephant']
#
# epoch: 0, iteration: 78000, simlex-999: SpearmanrResult(correlation=0.11402488690697192, pvalue=0.0004174933168278784), men: SpearmanrResult(correlation=0.11106415588696807, pvalue=1.528567436355582e-08), sim353: SpearmanrResult(correlation=0.18290810541705024, pvalue=0.0010316612071096492), nearest to monster: ['monster', 'mouse', 'bird', 'blade', 'tube', 'plain', 'horn', 'belt', 'elephant', 'cave']
#
# epoch: 0, iteration: 80000, simlex-999: SpearmanrResult(correlation=0.1143596905520433, pvalue=0.00040133970775166854), men: SpearmanrResult(correlation=0.11211564749287434, pvalue=1.115024669433565e-08), sim353: SpearmanrResult(correlation=0.18797063848663034, pvalue=0.0007402787624809048), nearest to monster: ['monster', 'bird', 'mouse', 'tube', 'blade', 'plain', 'belt', 'elephant', 'leg', 'triple']
#
# epoch: 0, iteration: 82000, simlex-999: SpearmanrResult(correlation=0.1162806651648727, pvalue=0.00031937602075473404), men: SpearmanrResult(correlation=0.11381072792609971, pvalue=6.664836195602085e-09), sim353: SpearmanrResult(correlation=0.18974323668799858, pvalue=0.0006577329602830077), nearest to monster: ['monster', 'bird', 'tube', 'mouse', 'elephant', 'blade', 'leg', 'belt', 'plain', 'horn']
#
# epoch: 0, iteration: 84000, simlex-999: SpearmanrResult(correlation=0.11489479036720938, pvalue=0.0003767277447218432), men: SpearmanrResult(correlation=0.11541121913902237, pvalue=4.071639644172881e-09), sim353: SpearmanrResult(correlation=0.19400911717698469, pvalue=0.0004927303488722429), nearest to monster: ['monster', 'bird', 'mouse', 'blade', 'tube', 'belt', 'elephant', 'triple', 'horn', 'cave']
#
# epoch: 0, iteration: 86000, simlex-999: SpearmanrResult(correlation=0.11781256045915833, pvalue=0.0002655266370940416), men: SpearmanrResult(correlation=0.11730818687389588, pvalue=2.2507510972401117e-09), sim353: SpearmanrResult(correlation=0.1975859209094848, pvalue=0.0003849291625404064), nearest to monster: ['monster', 'bird', 'belt', 'blade', 'elephant', 'tube', 'mouse', 'triangle', 'plain', 'leg']
#
# epoch: 0, iteration: 88000, simlex-999: SpearmanrResult(correlation=0.11873304934463363, pvalue=0.00023738841553420218), men: SpearmanrResult(correlation=0.11860546109263308, pvalue=1.4924804558738028e-09), sim353: SpearmanrResult(correlation=0.2000666342004715, pvalue=0.00032352436679496864), nearest to monster: ['monster', 'bird', 'blade', 'belt', 'elephant', 'triangle', 'mouse', 'tube', 'shield', 'ghost']
#
# epoch: 0, iteration: 90000, simlex-999: SpearmanrResult(correlation=0.11957891781730591, pvalue=0.00021401731213045388), men: SpearmanrResult(correlation=0.1197746371339062, pvalue=1.026740776058555e-09), sim353: SpearmanrResult(correlation=0.19860197641656727, pvalue=0.00035857317174329173), nearest to monster: ['monster', 'bird', 'blade', 'elephant', 'belt', 'mouse', 'triangle', 'tube', 'triple', 'diamond']
#
# epoch: 0, iteration: 92000, simlex-999: SpearmanrResult(correlation=0.12060193893696886, pvalue=0.0001886339107583196), men: SpearmanrResult(correlation=0.12109166826586396, pvalue=6.708063688387666e-10), sim353: SpearmanrResult(correlation=0.19950361708666883, pvalue=0.00033660145568120047), nearest to monster: ['monster', 'bird', 'blade', 'elephant', 'triangle', 'belt', 'crystal', 'diamond', 'triple', 'tube']
#
# epoch: 0, iteration: 94000, simlex-999: SpearmanrResult(correlation=0.12259203314313553, pvalue=0.00014713938706593265), men: SpearmanrResult(correlation=0.12270635007921855, pvalue=3.955880205389882e-10), sim353: SpearmanrResult(correlation=0.2036903868321528, pvalue=0.00025004714712691426), nearest to monster: ['monster', 'bird', 'blade', 'elephant', 'belt', 'triangle', 'leg', 'tube', 'mouse', 'buddha']
#
# epoch: 0, iteration: 96000, simlex-999: SpearmanrResult(correlation=0.12364210226203085, pvalue=0.00012886764758535512), men: SpearmanrResult(correlation=0.12427739835798972, pvalue=2.350801838641429e-10), sim353: SpearmanrResult(correlation=0.20296046083661548, pvalue=0.0002634603833610021), nearest to monster: ['monster', 'bird', 'elephant', 'triangle', 'blade', 'leg', 'belt', 'horn', 'legendary', 'ghost']
#
# epoch: 0, iteration: 98000, simlex-999: SpearmanrResult(correlation=0.1240628320242343, pvalue=0.00012216418073958182), men: SpearmanrResult(correlation=0.1248407366098221, pvalue=1.9475014160439383e-10), sim353: SpearmanrResult(correlation=0.20713780383462602, pvalue=0.00019488111765734927), nearest to monster: ['monster', 'bird', 'elephant', 'leg', 'triangle', 'blade', 'legendary', 'buddha', 'belt', 'demon']
#
# epoch: 0, iteration: 100000, simlex-999: SpearmanrResult(correlation=0.12525639236849007, pvalue=0.00010488919262756077), men: SpearmanrResult(correlation=0.1258997221064375, pvalue=1.3640650852181768e-10), sim353: SpearmanrResult(correlation=0.20946158950590868, pvalue=0.00016436104871267102), nearest to monster: ['monster', 'bird', 'elephant', 'leg', 'triangle', 'blade', 'legendary', 'horn', 'belt', 'boat']
#
# epoch: 0, iteration: 102000, simlex-999: SpearmanrResult(correlation=0.12580005136820877, pvalue=9.78083792161209e-05), men: SpearmanrResult(correlation=0.1272291973593904, pvalue=8.68690651997099e-11), sim353: SpearmanrResult(correlation=0.21242602432901017, pvalue=0.00013190404718379644), nearest to monster: ['monster', 'bird', 'elephant', 'leg', 'triangle', 'belt', 'boat', 'legendary', 'cartoon', 'demon']
#
# epoch: 0, iteration: 104000, simlex-999: SpearmanrResult(correlation=0.12720479506229884, pvalue=8.154128530344492e-05), men: SpearmanrResult(correlation=0.12797334209391323, pvalue=6.734199967923802e-11), sim353: SpearmanrResult(correlation=0.21471561493592864, pvalue=0.00011106061393215095), nearest to monster: ['monster', 'bird', 'elephant', 'triangle', 'leg', 'boat', 'belt', 'cartoon', 'giant', 'legendary']
#
# epoch: 0, iteration: 106000, simlex-999: SpearmanrResult(correlation=0.12661161184561306, pvalue=8.80716197329598e-05), men: SpearmanrResult(correlation=0.12917414793531018, pvalue=4.4514348474433996e-11), sim353: SpearmanrResult(correlation=0.21484204425498346, pvalue=0.00011000494516047559), nearest to monster: ['monster', 'bird', 'elephant', 'triangle', 'boat', 'belt', 'leg', 'giant', 'demon', 'blade']
#
# epoch: 0, iteration: 108000, simlex-999: SpearmanrResult(correlation=0.1274117668499864, pvalue=7.937231361164341e-05), men: SpearmanrResult(correlation=0.12877777044351846, pvalue=5.105404626368822e-11), sim353: SpearmanrResult(correlation=0.21716952668998118, pvalue=9.217640268075705e-05), nearest to monster: ['monster', 'bird', 'elephant', 'giant', 'boat', 'belt', 'legendary', 'leg', 'ghost', 'triangle']
#
# epoch: 0, iteration: 110000, simlex-999: SpearmanrResult(correlation=0.1287800542286292, pvalue=6.634641543787218e-05), men: SpearmanrResult(correlation=0.12996913025652287, pvalue=3.3772101604500245e-11), sim353: SpearmanrResult(correlation=0.2231423878243933, pvalue=5.804648844930827e-05), nearest to monster: ['monster', 'bird', 'elephant', 'belt', 'triangle', 'giant', 'ghost', 'legendary', 'demon', 'cartoon']
#
# epoch: 0, iteration: 112000, simlex-999: SpearmanrResult(correlation=0.1290487720237621, pvalue=6.403787977505321e-05), men: SpearmanrResult(correlation=0.13167819824393648, pvalue=1.8545129037558584e-11), sim353: SpearmanrResult(correlation=0.22082507148961192, pvalue=6.955776948100314e-05), nearest to monster: ['monster', 'bird', 'elephant', 'belt', 'giant', 'horn', 'triangle', 'angel', 'legendary', 'demon']
#
# epoch: 0, iteration: 114000, simlex-999: SpearmanrResult(correlation=0.12984670182227118, pvalue=5.76221308835562e-05), men: SpearmanrResult(correlation=0.13169666074701, pvalue=1.8424646249435018e-11), sim353: SpearmanrResult(correlation=0.2191112518313131, pvalue=7.941908391508048e-05), nearest to monster: ['monster', 'bird', 'elephant', 'belt', 'triangle', 'horn', 'ghost', 'legendary', 'giant', 'cartoon']
#
# epoch: 0, iteration: 116000, simlex-999: SpearmanrResult(correlation=0.13121642660097535, pvalue=4.800318344442046e-05), men: SpearmanrResult(correlation=0.13270052683966205, pvalue=1.290892781352572e-11), sim353: SpearmanrResult(correlation=0.2203929198113222, pvalue=7.192948795469513e-05), nearest to monster: ['monster', 'bird', 'elephant', 'belt', 'triangle', 'giant', 'horn', 'ghost', 'legendary', 'angel']
#
# epoch: 0, iteration: 118000, simlex-999: SpearmanrResult(correlation=0.13146126835181915, pvalue=4.645251557213645e-05), men: SpearmanrResult(correlation=0.13326692726683884, pvalue=1.0548669224664914e-11), sim353: SpearmanrResult(correlation=0.2274622410636192, pvalue=4.121971298610341e-05), nearest to monster: ['monster', 'bird', 'giant', 'elephant', 'triangle', 'belt', 'boat', 'demon', 'flower', 'epic']
#
# epoch: 1, iteration: 0, simlex-999: SpearmanrResult(correlation=0.13180017687975817, pvalue=4.4384190469044874e-05), men: SpearmanrResult(correlation=0.13394813530385904, pvalue=8.264890718900549e-12), sim353: SpearmanrResult(correlation=0.2276428279710995, pvalue=4.062816445304583e-05), nearest to monster: ['monster', 'bird', 'triangle', 'elephant', 'giant', 'demon', 'belt', 'flower', 'boat', 'mine']
#
# epoch: 1, iteration: 2000, simlex-999: SpearmanrResult(correlation=0.1329670900382602, pvalue=3.7909949526342995e-05), men: SpearmanrResult(correlation=0.1334481333038959, pvalue=9.886988132704662e-12), sim353: SpearmanrResult(correlation=0.23100207715896873, pvalue=3.098327502071649e-05), nearest to monster: ['monster', 'bird', 'triangle', 'elephant', 'flower', 'demon', 'giant', 'belt', 'mine', 'ghost']
#
# epoch: 1, iteration: 4000, simlex-999: SpearmanrResult(correlation=0.13429849267503222, pvalue=3.161778070379242e-05), men: SpearmanrResult(correlation=0.1349888743006904, pvalue=5.67952065584469e-12), sim353: SpearmanrResult(correlation=0.2290949167583726, pvalue=3.615467617821276e-05), nearest to monster: ['monster', 'bird', 'triangle', 'elephant', 'demon', 'ghost', 'mine', 'flower', 'belt', 'boat']
#
# epoch: 1, iteration: 6000, simlex-999: SpearmanrResult(correlation=0.13431277338290312, pvalue=3.155599791920174e-05), men: SpearmanrResult(correlation=0.13600564712377086, pvalue=3.925746240065866e-12), sim353: SpearmanrResult(correlation=0.2286062045952425, pvalue=3.760554706261689e-05), nearest to monster: ['monster', 'bird', 'elephant', 'triangle', 'flower', 'demon', 'ghost', 'buddha', 'mine', 'legendary']
#
# epoch: 1, iteration: 8000, simlex-999: SpearmanrResult(correlation=0.13575528680736634, pvalue=2.587239632842364e-05), men: SpearmanrResult(correlation=0.13647146559188875, pvalue=3.3116205402571342e-12), sim353: SpearmanrResult(correlation=0.2259999861761297, pvalue=4.631821014424681e-05), nearest to monster: ['monster', 'bird', 'triangle', 'elephant', 'belt', 'ghost', 'flower', 'buddha', 'demon', 'giant']
#
# epoch: 1, iteration: 10000, simlex-999: SpearmanrResult(correlation=0.13596033745458727, pvalue=2.5148164973309882e-05), men: SpearmanrResult(correlation=0.13753776401137405, pvalue=2.2385556585248543e-12), sim353: SpearmanrResult(correlation=0.2283213689509976, pvalue=3.8476351381980874e-05), nearest to monster: ['monster', 'bird', 'triangle', 'elephant', 'belt', 'ghost', 'flower', 'buddha', 'demon', 'mine']
#
# epoch: 1, iteration: 12000, simlex-999: SpearmanrResult(correlation=0.1379624767968454, pvalue=1.9018850896683788e-05), men: SpearmanrResult(correlation=0.13833354242299123, pvalue=1.6679352007123597e-12), sim353: SpearmanrResult(correlation=0.22838088684681, pvalue=3.829283272802703e-05), nearest to monster: ['monster', 'bird', 'triangle', 'belt', 'elephant', 'demon', 'flower', 'ghost', 'buddha', 'giant']
#
# epoch: 1, iteration: 14000, simlex-999: SpearmanrResult(correlation=0.13941631760316558, pvalue=1.5489285871897254e-05), men: SpearmanrResult(correlation=0.13885355346690226, pvalue=1.3749123700009663e-12), sim353: SpearmanrResult(correlation=0.22999212131201607, pvalue=3.362775948546969e-05), nearest to monster: ['monster', 'bird', 'triangle', 'belt', 'elephant', 'ghost', 'buddha', 'demon', 'flower', 'mine']
#
# epoch: 1, iteration: 16000, simlex-999: SpearmanrResult(correlation=0.14091354204983206, pvalue=1.2510876868144813e-05), men: SpearmanrResult(correlation=0.13949129080100375, pvalue=1.083788936473265e-12), sim353: SpearmanrResult(correlation=0.2304373965014943, pvalue=3.243656898127559e-05), nearest to monster: ['monster', 'bird', 'triangle', 'belt', 'elephant', 'demon', 'flower', 'ghost', 'blade', 'buddha']
#
# epoch: 1, iteration: 18000, simlex-999: SpearmanrResult(correlation=0.14130625633199265, pvalue=1.1825106175589526e-05), men: SpearmanrResult(correlation=0.1409839421895531, pvalue=6.183551858320513e-13), sim353: SpearmanrResult(correlation=0.23106677052398214, pvalue=3.0820765074187075e-05), nearest to monster: ['monster', 'bird', 'triangle', 'belt', 'elephant', 'demon', 'flower', 'ghost', 'buddha', 'giant']
#
# epoch: 1, iteration: 20000, simlex-999: SpearmanrResult(correlation=0.1430206046859954, pvalue=9.229234716684688e-06), men: SpearmanrResult(correlation=0.1413960668058551, pvalue=5.290430102827949e-13), sim353: SpearmanrResult(correlation=0.23431788937318604, pvalue=2.361709788056063e-05), nearest to monster: ['monster', 'bird', 'triangle', 'belt', 'elephant', 'flower', 'demon', 'ghost', 'buddha', 'giant']
#
# epoch: 1, iteration: 22000, simlex-999: SpearmanrResult(correlation=0.1450276683156251, pvalue=6.879660282636848e-06), men: SpearmanrResult(correlation=0.14194186442731496, pvalue=4.2999574021355706e-13), sim353: SpearmanrResult(correlation=0.23838506881248803, pvalue=1.683671246221312e-05), nearest to monster: ['monster', 'bird', 'triangle', 'belt', 'elephant', 'demon', 'ghost', 'flower', 'giant', 'buddha']
#
# epoch: 1, iteration: 24000, simlex-999: SpearmanrResult(correlation=0.14548743888271976, pvalue=6.428308596115489e-06), men: SpearmanrResult(correlation=0.14228802137316493, pvalue=3.768654793561971e-13), sim353: SpearmanrResult(correlation=0.2395403074734423, pvalue=1.5276974336185742e-05), nearest to monster: ['monster', 'triangle', 'bird', 'elephant', 'belt', 'demon', 'ghost', 'flower', 'mine', 'giant']
#
# epoch: 1, iteration: 26000, simlex-999: SpearmanrResult(correlation=0.14609721439530657, pvalue=5.873175838407176e-06), men: SpearmanrResult(correlation=0.14209251440853277, pvalue=4.0602586172596667e-13), sim353: SpearmanrResult(correlation=0.23975268654887213, pvalue=1.500557692457392e-05), nearest to monster: ['monster', 'triangle', 'bird', 'belt', 'giant', 'flower', 'demon', 'elephant', 'mine', 'ghost']
#
# epoch: 1, iteration: 28000, simlex-999: SpearmanrResult(correlation=0.14783145830112077, pvalue=4.533712543814635e-06), men: SpearmanrResult(correlation=0.142892986265821, pvalue=2.9905227663565517e-13), sim353: SpearmanrResult(correlation=0.2384965262384969, pvalue=1.6679886643829338e-05), nearest to monster: ['monster', 'triangle', 'bird', 'giant', 'belt', 'flower', 'elephant', 'demon', 'mine', 'buddha']
#
# epoch: 1, iteration: 30000, simlex-999: SpearmanrResult(correlation=0.14886085788355619, pvalue=3.882572147543353e-06), men: SpearmanrResult(correlation=0.14345371893876807, pvalue=2.411395096807692e-13), sim353: SpearmanrResult(correlation=0.24119534858867173, pvalue=1.3279562326695212e-05), nearest to monster: ['monster', 'triangle', 'giant', 'bird', 'demon', 'belt', 'elephant', 'flower', 'mine', 'ghost']
#
# epoch: 1, iteration: 32000, simlex-999: SpearmanrResult(correlation=0.14826903605058245, pvalue=4.2450870162241585e-06), men: SpearmanrResult(correlation=0.14292064364686516, pvalue=2.9590005414435007e-13), sim353: SpearmanrResult(correlation=0.2455122444169256, pvalue=9.170885949044116e-06), nearest to monster: ['monster', 'giant', 'triangle', 'bird', 'mine', 'demon', 'belt', 'flower', 'elephant', 'clown']
#
# epoch: 1, iteration: 34000, simlex-999: SpearmanrResult(correlation=0.14772874639192546, pvalue=4.604131691467388e-06), men: SpearmanrResult(correlation=0.14375644453138436, pvalue=2.1460914887264587e-13), sim353: SpearmanrResult(correlation=0.2466066713147672, pvalue=8.340267137959956e-06), nearest to monster: ['monster', 'giant', 'triangle', 'bird', 'mine', 'demon', 'elephant', 'flower', 'belt', 'robot']
#
# epoch: 1, iteration: 36000, simlex-999: SpearmanrResult(correlation=0.14931017670371174, pvalue=3.627332225455767e-06), men: SpearmanrResult(correlation=0.144989800683895, pvalue=1.3313772094570762e-13), sim353: SpearmanrResult(correlation=0.24505661828904524, pvalue=9.539378663585767e-06), nearest to monster: ['monster', 'giant', 'triangle', 'bird', 'demon', 'mine', 'robot', 'belt', 'flower', 'elephant']
#
# epoch: 1, iteration: 38000, simlex-999: SpearmanrResult(correlation=0.1502446871503629, pvalue=3.1469450695082534e-06), men: SpearmanrResult(correlation=0.14627644187650768, pvalue=8.055471698970356e-14), sim353: SpearmanrResult(correlation=0.24807761359698702, pvalue=7.336042480812721e-06), nearest to monster: ['monster', 'giant', 'triangle', 'bird', 'demon', 'robot', 'mine', 'clown', 'flower', 'elephant']
#
# epoch: 1, iteration: 40000, simlex-999: SpearmanrResult(correlation=0.15075177546165633, pvalue=2.912420556544115e-06), men: SpearmanrResult(correlation=0.14649619208825093, pvalue=7.389709675559248e-14), sim353: SpearmanrResult(correlation=0.24522648458175195, pvalue=9.400381315321747e-06), nearest to monster: ['monster', 'giant', 'triangle', 'bird', 'flower', 'clown', 'ghost', 'demon', 'blade', 'mine']
#
# epoch: 1, iteration: 42000, simlex-999: SpearmanrResult(correlation=0.15272058802439767, pvalue=2.1509009998239263e-06), men: SpearmanrResult(correlation=0.14765529746012943, pvalue=4.6782040458852825e-14), sim353: SpearmanrResult(correlation=0.24542555530780757, pvalue=9.239937387027611e-06), nearest to monster: ['monster', 'giant', 'bird', 'triangle', 'flower', 'demon', 'blade', 'horn', 'clown', 'elephant']
#
# epoch: 1, iteration: 44000, simlex-999: SpearmanrResult(correlation=0.15349272063815084, pvalue=1.907843438837417e-06), men: SpearmanrResult(correlation=0.14848205381556875, pvalue=3.368939163256822e-14), sim353: SpearmanrResult(correlation=0.2493232381307743, pvalue=6.57668665441914e-06), nearest to monster: ['monster', 'giant', 'bird', 'triangle', 'flower', 'demon', 'clown', 'blade', 'hammer', 'horn']
#
# epoch: 1, iteration: 46000, simlex-999: SpearmanrResult(correlation=0.15413853481093104, pvalue=1.7249969661322373e-06), men: SpearmanrResult(correlation=0.15043687122599986, pvalue=1.538681518188792e-14), sim353: SpearmanrResult(correlation=0.249382571188401, pvalue=6.5424515011938e-06), nearest to monster: ['monster', 'giant', 'triangle', 'bird', 'flower', 'demon', 'clown', 'robot', 'ghost', 'elephant']
#
# epoch: 1, iteration: 48000, simlex-999: SpearmanrResult(correlation=0.15547621923556834, pvalue=1.3982643923839315e-06), men: SpearmanrResult(correlation=0.1517011333787633, pvalue=9.21783693595779e-15), sim353: SpearmanrResult(correlation=0.25170949910884144, pvalue=5.325988524291757e-06), nearest to monster: ['monster', 'giant', 'triangle', 'bird', 'clown', 'flower', 'demon', 'robot', 'hammer', 'ghost']
#
# epoch: 1, iteration: 50000, simlex-999: SpearmanrResult(correlation=0.1566577926464333, pvalue=1.159826809572053e-06), men: SpearmanrResult(correlation=0.1530239589267643, pvalue=5.367550903018303e-15), sim353: SpearmanrResult(correlation=0.2532379260668304, pvalue=4.647742558296603e-06), nearest to monster: ['monster', 'giant', 'bird', 'triangle', 'clown', 'robot', 'flower', 'demon', 'ghost', 'mine']
#
# epoch: 1, iteration: 52000, simlex-999: SpearmanrResult(correlation=0.15721862054058305, pvalue=1.0608239658498056e-06), men: SpearmanrResult(correlation=0.15375617174423695, pvalue=3.9708940637768406e-15), sim353: SpearmanrResult(correlation=0.2540807881938626, pvalue=4.309799783070389e-06), nearest to monster: ['monster', 'giant', 'bird', 'robot', 'demon', 'triangle', 'clown', 'flower', 'horn', 'hammer']
#
# epoch: 1, iteration: 54000, simlex-999: SpearmanrResult(correlation=0.15864624213522202, pvalue=8.440943729147536e-07), men: SpearmanrResult(correlation=0.15412898880185297, pvalue=3.404085346177422e-15), sim353: SpearmanrResult(correlation=0.2554136563513252, pvalue=3.822759866102747e-06), nearest to monster: ['monster', 'giant', 'bird', 'horn', 'triangle', 'demon', 'clown', 'robot', 'hammer', 'flower']
#
# epoch: 1, iteration: 56000, simlex-999: SpearmanrResult(correlation=0.1593300368403939, pvalue=7.560314750292275e-07), men: SpearmanrResult(correlation=0.15491303358518643, pvalue=2.459206628400434e-15), sim353: SpearmanrResult(correlation=0.2581731056264269, pvalue=2.9760233020546984e-06), nearest to monster: ['monster', 'giant', 'bird', 'triangle', 'clown', 'hammer', 'demon', 'robot', 'horn', 'blade']
#
# epoch: 1, iteration: 58000, simlex-999: SpearmanrResult(correlation=0.1596866986412067, pvalue=7.136756700245956e-07), men: SpearmanrResult(correlation=0.15534963878837643, pvalue=2.0504373069452714e-15), sim353: SpearmanrResult(correlation=0.25836274960500916, pvalue=2.924943394984887e-06), nearest to monster: ['monster', 'giant', 'triangle', 'bird', 'robot', 'clown', 'hammer', 'demon', 'horn', 'blade']
#
# epoch: 1, iteration: 60000, simlex-999: SpearmanrResult(correlation=0.1601171792278652, pvalue=6.655891796990141e-07), men: SpearmanrResult(correlation=0.15434227525542413, pvalue=3.1164495800646934e-15), sim353: SpearmanrResult(correlation=0.2592667931715255, pvalue=2.6927360042333913e-06), nearest to monster: ['monster', 'giant', 'triangle', 'bird', 'clown', 'robot', 'hammer', 'demon', 'horn', 'blade']
#
# epoch: 1, iteration: 62000, simlex-999: SpearmanrResult(correlation=0.1598124089513845, pvalue=6.992982548090954e-07), men: SpearmanrResult(correlation=0.15405551453323255, pvalue=3.5090992930562474e-15), sim353: SpearmanrResult(correlation=0.2571661071904463, pvalue=3.261839847674284e-06), nearest to monster: ['monster', 'giant', 'triangle', 'robot', 'bird', 'demon', 'clown', 'blade', 'hammer', 'horn']
#
# epoch: 1, iteration: 64000, simlex-999: SpearmanrResult(correlation=0.1606027302043762, pvalue=6.150916371255266e-07), men: SpearmanrResult(correlation=0.15509621353365605, pvalue=2.278763961379168e-15), sim353: SpearmanrResult(correlation=0.2598811953009674, pvalue=2.5450897990976933e-06), nearest to monster: ['monster', 'giant', 'triangle', 'robot', 'clown', 'demon', 'bird', 'blade', 'hammer', 'bullet']
#
# epoch: 1, iteration: 66000, simlex-999: SpearmanrResult(correlation=0.16164749891054506, pvalue=5.186349456874364e-07), men: SpearmanrResult(correlation=0.15561928271913295, pvalue=1.832210411965522e-15), sim353: SpearmanrResult(correlation=0.2631299112537565, pvalue=1.8844117098245348e-06), nearest to monster: ['monster', 'giant', 'triangle', 'robot', 'clown', 'demon', 'blade', 'bird', 'flower', 'bullet']
#
# epoch: 1, iteration: 68000, simlex-999: SpearmanrResult(correlation=0.16154925814480997, pvalue=5.270448502314334e-07), men: SpearmanrResult(correlation=0.15576297410564377, pvalue=1.725428415621114e-15), sim353: SpearmanrResult(correlation=0.26282659179093637, pvalue=1.9383674498285163e-06), nearest to monster: ['monster', 'giant', 'triangle', 'clown', 'robot', 'demon', 'bird', 'blade', 'flower', 'bullet']
#
# epoch: 1, iteration: 70000, simlex-999: SpearmanrResult(correlation=0.1599853708860781, pvalue=6.799714073071462e-07), men: SpearmanrResult(correlation=0.15728083796798115, pvalue=9.118454039781388e-16), sim353: SpearmanrResult(correlation=0.26281069570696164, pvalue=1.9412354657279714e-06), nearest to monster: ['monster', 'giant', 'triangle', 'clown', 'robot', 'demon', 'blade', 'flower', 'ghost', 'bird']
#
# epoch: 1, iteration: 72000, simlex-999: SpearmanrResult(correlation=0.16033942339120516, pvalue=6.419994400734508e-07), men: SpearmanrResult(correlation=0.1572903799426211, pvalue=9.081787682673746e-16), sim353: SpearmanrResult(correlation=0.26375466432160055, pvalue=1.7777683247043304e-06), nearest to monster: ['monster', 'giant', 'triangle', 'robot', 'demon', 'clown', 'blade', 'bird', 'ghost', 'hammer']
#
# epoch: 1, iteration: 74000, simlex-999: SpearmanrResult(correlation=0.16086809636955823, pvalue=5.890730837549319e-07), men: SpearmanrResult(correlation=0.1577505779790487, pvalue=7.475642007694544e-16), sim353: SpearmanrResult(correlation=0.2638831268606987, pvalue=1.7565674460551072e-06), nearest to monster: ['monster', 'giant', 'triangle', 'robot', 'clown', 'demon', 'blade', 'bird', 'hammer', 'flower']
#
# epoch: 1, iteration: 76000, simlex-999: SpearmanrResult(correlation=0.1615877500599158, pvalue=5.237342226528971e-07), men: SpearmanrResult(correlation=0.1577026347097894, pvalue=7.628968667612668e-16), sim353: SpearmanrResult(correlation=0.263576480310535, pvalue=1.8075805062647394e-06), nearest to monster: ['monster', 'giant', 'triangle', 'robot', 'demon', 'clown', 'bird', 'hammer', 'blade', 'ghost']
#
# epoch: 1, iteration: 78000, simlex-999: SpearmanrResult(correlation=0.1612802570160111, pvalue=5.507500460098273e-07), men: SpearmanrResult(correlation=0.15900971346385961, pvalue=4.3762028967444095e-16), sim353: SpearmanrResult(correlation=0.2654677446271564, pvalue=1.5141527506780128e-06), nearest to monster: ['monster', 'giant', 'triangle', 'demon', 'clown', 'robot', 'bird', 'hammer', 'ghost', 'trilogy']
#
# epoch: 1, iteration: 80000, simlex-999: SpearmanrResult(correlation=0.1616796054523012, pvalue=5.159145855261156e-07), men: SpearmanrResult(correlation=0.15981021495485515, pvalue=3.106478465980434e-16), sim353: SpearmanrResult(correlation=0.26785141787062294, pvalue=1.2088393934017524e-06), nearest to monster: ['monster', 'giant', 'triangle', 'demon', 'bird', 'robot', 'hammer', 'clown', 'ghost', 'trilogy']
#
# epoch: 1, iteration: 82000, simlex-999: SpearmanrResult(correlation=0.16275520915401806, pvalue=4.32318496200035e-07), men: SpearmanrResult(correlation=0.16025974417695296, pvalue=2.5606863529349347e-16), sim353: SpearmanrResult(correlation=0.26582577619295933, pvalue=1.4639962885174405e-06), nearest to monster: ['monster', 'giant', 'triangle', 'demon', 'clown', 'robot', 'bird', 'hammer', 'trilogy', 'blade']
#
# epoch: 1, iteration: 84000, simlex-999: SpearmanrResult(correlation=0.16301563425648904, pvalue=4.141329249059158e-07), men: SpearmanrResult(correlation=0.16132578513310433, pvalue=1.615834190872699e-16), sim353: SpearmanrResult(correlation=0.2648012181293322, pvalue=1.611938359119966e-06), nearest to monster: ['monster', 'giant', 'demon', 'clown', 'triangle', 'bird', 'robot', 'hammer', 'trilogy', 'dalek']
#
# epoch: 1, iteration: 86000, simlex-999: SpearmanrResult(correlation=0.1647467614919778, pvalue=3.1068791537723676e-07), men: SpearmanrResult(correlation=0.16166886218716175, pvalue=1.3923741287712592e-16), sim353: SpearmanrResult(correlation=0.26524113301142366, pvalue=1.5467438991677257e-06), nearest to monster: ['monster', 'giant', 'demon', 'triangle', 'robot', 'bird', 'clown', 'hammer', 'trilogy', 'ghost']
#
# epoch: 1, iteration: 88000, simlex-999: SpearmanrResult(correlation=0.16444091316545104, pvalue=3.269422675048473e-07), men: SpearmanrResult(correlation=0.16255654275144887, pvalue=9.459096026353252e-17), sim353: SpearmanrResult(correlation=0.26733350127414396, pvalue=1.269693042679447e-06), nearest to monster: ['monster', 'giant', 'demon', 'robot', 'triangle', 'clown', 'bird', 'hammer', 'trilogy', 'ghost']
#
# epoch: 1, iteration: 90000, simlex-999: SpearmanrResult(correlation=0.16618982131612242, pvalue=2.439390976265818e-07), men: SpearmanrResult(correlation=0.16293006420077577, pvalue=8.033692955291493e-17), sim353: SpearmanrResult(correlation=0.2665009900855139, pvalue=1.3736999417312206e-06), nearest to monster: ['monster', 'giant', 'robot', 'demon', 'triangle', 'bird', 'clown', 'hammer', 'finger', 'ghost']
#
# epoch: 1, iteration: 92000, simlex-999: SpearmanrResult(correlation=0.1670797308974068, pvalue=2.0991834254495862e-07), men: SpearmanrResult(correlation=0.16322211738410353, pvalue=7.068637806426794e-17), sim353: SpearmanrResult(correlation=0.26748543826283266, pvalue=1.2515434001356929e-06), nearest to monster: ['monster', 'giant', 'robot', 'demon', 'bird', 'triangle', 'hammer', 'finger', 'clown', 'dalek']
#
# epoch: 1, iteration: 94000, simlex-999: SpearmanrResult(correlation=0.1678816895624341, pvalue=1.8321871930427102e-07), men: SpearmanrResult(correlation=0.16456754644367014, pvalue=3.9081473914015113e-17), sim353: SpearmanrResult(correlation=0.26978112852988095, pvalue=1.0057757642477037e-06), nearest to monster: ['monster', 'giant', 'robot', 'demon', 'triangle', 'hammer', 'bird', 'clown', 'finger', 'dalek']
#
# epoch: 1, iteration: 96000, simlex-999: SpearmanrResult(correlation=0.1672466213372283, pvalue=2.0406977279400413e-07), men: SpearmanrResult(correlation=0.16593647736486192, pvalue=2.127547152511106e-17), sim353: SpearmanrResult(correlation=0.2695944419622707, pvalue=1.0238938580640236e-06), nearest to monster: ['monster', 'giant', 'triangle', 'robot', 'demon', 'bird', 'hammer', 'dalek', 'finger', 'blade']
#
# epoch: 1, iteration: 98000, simlex-999: SpearmanrResult(correlation=0.16815595367680172, pvalue=1.748639101034198e-07), men: SpearmanrResult(correlation=0.16673827418599402, pvalue=1.4864537401562882e-17), sim353: SpearmanrResult(correlation=0.2677889425638385, pvalue=1.2160291470411576e-06), nearest to monster: ['monster', 'giant', 'triangle', 'robot', 'demon', 'bird', 'hammer', 'clown', 'finger', 'dalek']
#
# epoch: 1, iteration: 100000, simlex-999: SpearmanrResult(correlation=0.16928859324657264, pvalue=1.440930450059348e-07), men: SpearmanrResult(correlation=0.16707525062003986, pvalue=1.277825888288581e-17), sim353: SpearmanrResult(correlation=0.26981125715415866, pvalue=1.0028806913012364e-06), nearest to monster: ['monster', 'giant', 'robot', 'triangle', 'hammer', 'demon', 'clown', 'bird', 'finger', 'snake']
#
# epoch: 1, iteration: 102000, simlex-999: SpearmanrResult(correlation=0.16999343815731738, pvalue=1.2765866187255691e-07), men: SpearmanrResult(correlation=0.16745973015882878, pvalue=1.0748952280980737e-17), sim353: SpearmanrResult(correlation=0.27011697951339353, pvalue=9.73951657200918e-07), nearest to monster: ['monster', 'giant', 'robot', 'triangle', 'demon', 'hammer', 'clown', 'finger', 'bird', 'snake']
#
# epoch: 1, iteration: 104000, simlex-999: SpearmanrResult(correlation=0.16986968295312643, pvalue=1.3040678118151263e-07), men: SpearmanrResult(correlation=0.1678227694232147, pvalue=9.126101606419232e-18), sim353: SpearmanrResult(correlation=0.2687249879713495, pvalue=1.112474109566772e-06), nearest to monster: ['monster', 'giant', 'hammer', 'robot', 'clown', 'demon', 'triangle', 'bird', 'killer', 'stone']
#
# epoch: 1, iteration: 106000, simlex-999: SpearmanrResult(correlation=0.1696726221056848, pvalue=1.3490104558125683e-07), men: SpearmanrResult(correlation=0.16827590204583126, pvalue=7.436041722642902e-18), sim353: SpearmanrResult(correlation=0.27056706049570134, pvalue=9.32813256551908e-07), nearest to monster: ['monster', 'giant', 'hammer', 'clown', 'robot', 'triangle', 'demon', 'stone', 'bird', 'snake']
#
# epoch: 1, iteration: 108000, simlex-999: SpearmanrResult(correlation=0.16844859876453594, pvalue=1.6635496829429564e-07), men: SpearmanrResult(correlation=0.168882680212044, pvalue=5.647445229673742e-18), sim353: SpearmanrResult(correlation=0.27269417833734316, pvalue=7.59899943956712e-07), nearest to monster: ['monster', 'giant', 'clown', 'triangle', 'robot', 'hammer', 'demon', 'snake', 'bird', 'stone']
#
# epoch: 1, iteration: 110000, simlex-999: SpearmanrResult(correlation=0.16788250501054588, pvalue=1.8319331673792565e-07), men: SpearmanrResult(correlation=0.1688704768846478, pvalue=5.678838862866351e-18), sim353: SpearmanrResult(correlation=0.2755837536952148, pvalue=5.735681827293435e-07), nearest to monster: ['monster', 'giant', 'clown', 'robot', 'hammer', 'triangle', 'demon', 'snake', 'bird', 'killer']
#
# epoch: 1, iteration: 112000, simlex-999: SpearmanrResult(correlation=0.1666151949862166, pvalue=2.2706194409132408e-07), men: SpearmanrResult(correlation=0.1698657463068527, pvalue=3.608430815531449e-18), sim353: SpearmanrResult(correlation=0.2750427323255167, pvalue=6.047369252904138e-07), nearest to monster: ['monster', 'giant', 'clown', 'robot', 'hammer', 'triangle', 'demon', 'snake', 'stone', 'bird']
#
# epoch: 1, iteration: 114000, simlex-999: SpearmanrResult(correlation=0.1671927810301207, pvalue=2.0593917583849435e-07), men: SpearmanrResult(correlation=0.16971147784078008, pvalue=3.871889486411046e-18), sim353: SpearmanrResult(correlation=0.2753174018695452, pvalue=5.887152461927836e-07), nearest to monster: ['monster', 'giant', 'clown', 'hammer', 'robot', 'triangle', 'stone', 'demon', 'snake', 'bird']
#
# epoch: 1, iteration: 116000, simlex-999: SpearmanrResult(correlation=0.1668737680539931, pvalue=2.1735937366392574e-07), men: SpearmanrResult(correlation=0.17057110307859263, pvalue=2.612279627975005e-18), sim353: SpearmanrResult(correlation=0.27780624804070503, pvalue=4.6095568075537e-07), nearest to monster: ['monster', 'giant', 'clown', 'hammer', 'robot', 'demon', 'triangle', 'snake', 'stone', 'bird']
#
# epoch: 1, iteration: 118000, simlex-999: SpearmanrResult(correlation=0.1681734886854761, pvalue=1.7434244429097867e-07), men: SpearmanrResult(correlation=0.1706465597538419, pvalue=2.5233376310706023e-18), sim353: SpearmanrResult(correlation=0.27824228132089557, pvalue=4.415068101664366e-07), nearest to monster: ['monster', 'giant', 'clown', 'hammer', 'robot', 'snake', 'triangle', 'demon', 'stone', 'reads']

# %%
model.load_state_dict(torch.load("embedding-{}.th".format(EMBEDDING_SIZE)))

# %% [markdown]
# ## 在 MEN 和 Simplex-999 数据集上做评估

# %%
embedding_weights = model.input_embeddings()
print("simlex-999", evaluate("simlex-999.txt", embedding_weights))
print("men", evaluate("men.txt", embedding_weights))
print("wordsim353", evaluate("wordsim353.csv", embedding_weights))
# Out:
# simlex-999 SpearmanrResult(correlation=0.17251697429101504, pvalue=7.863946056740345e-08)
# men SpearmanrResult(correlation=0.1778096817088841, pvalue=7.565661657312768e-20)
# wordsim353 SpearmanrResult(correlation=0.27153702278146635, pvalue=8.842165885381714e-07)

# %% [markdown]
# ## 寻找nearest neighbors

# %%
for word in ["good", "fresh", "monster", "green", "like", "america", "chicago", "work", "computer", "language"]:
    print(word, find_nearest(word))
# Out:
# good ['good', 'bad', 'perfect', 'hard', 'questions', 'alone', 'money', 'false', 'truth', 'experience']
# fresh ['fresh', 'grain', 'waste', 'cooling', 'lighter', 'dense', 'mild', 'sized', 'warm', 'steel']
# monster ['monster', 'giant', 'robot', 'hammer', 'clown', 'bull', 'demon', 'triangle', 'storyline', 'slogan']
# green ['green', 'blue', 'yellow', 'white', 'cross', 'orange', 'black', 'red', 'mountain', 'gold']
# like ['like', 'unlike', 'etc', 'whereas', 'animals', 'soft', 'amongst', 'similarly', 'bear', 'drink']
# america ['america', 'africa', 'korea', 'india', 'australia', 'turkey', 'pakistan', 'mexico', 'argentina', 'carolina']
# chicago ['chicago', 'boston', 'illinois', 'texas', 'london', 'indiana', 'massachusetts', 'florida', 'berkeley', 'michigan']
# work ['work', 'writing', 'job', 'marx', 'solo', 'label', 'recording', 'nietzsche', 'appearance', 'stage']
# computer ['computer', 'digital', 'electronic', 'audio', 'video', 'graphics', 'hardware', 'software', 'computers', 'program']
# language ['language', 'languages', 'alphabet', 'arabic', 'grammar', 'pronunciation', 'dialect', 'programming', 'chinese', 'spelling']

# %% [markdown]
# ## 单词之间的关系

# %%
man_idx = word_to_idx["man"] 
king_idx = word_to_idx["king"] 
woman_idx = word_to_idx["woman"]
embedding = embedding_weights[woman_idx] - embedding_weights[man_idx] + embedding_weights[king_idx]
cos_dis = np.array([scipy.spatial.distance.cosine(e, embedding) for e in embedding_weights])
for i in cos_dis.argsort()[:20]:
    print(idx_to_word[i])
# Out:
# king
# henry
# charles
# pope
# queen
# iii
# prince
# elizabeth
# alexander
# constantine
# edward
# son
# iv
# louis
# emperor
# mary
# james
# joseph
# frederick
# francis
